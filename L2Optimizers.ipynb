# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense,Flatten
import matplotlib.pyplot as plt
from tensorflow.keras.optimizers import SGD,Adam,RMSprop,Adagrad,Adadelta,Adamax,Nadam

# %%
mnist=tf.keras.datasets.mnist
(x_train,y_train),(x_test,y_test)= mnist.load_data()
# Out:
# ...
# 11490434/11490434 [==============================] - 0s 0us/step

# %%
x_train,x_test=x_train/255.0,x_test/255.0

model=Sequential([Flatten(input_shape=(28,28)),
                  Dense(128,activation='relu'),
                  Dense(10,activation='softmax')
                  ])

# %%
model.compile(optimizer=SGD(learning_rate=0.01),
                          loss='sparse_categorical_crossentropy',
                          metrics=['accuracy'])
SGDvals = model.fit(x_train,y_train,epochs=10)
# Out:
# Epoch 1/10
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.6536 - accuracy: 0.8326
# Epoch 2/10
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.3365 - accuracy: 0.9060
# Epoch 3/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.2864 - accuracy: 0.9193
# Epoch 4/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2563 - accuracy: 0.9282
# Epoch 5/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.2335 - accuracy: 0.9346
# Epoch 6/10
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.2153 - accuracy: 0.9396
# Epoch 7/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2000 - accuracy: 0.9441
# Epoch 8/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.1871 - accuracy: 0.9481
# Epoch 9/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1757 - accuracy: 0.9507
# Epoch 10/10
# ...

# %%
SGDLoss=SGDvals.history['loss']
SGDAccuracy=SGDvals.history['accuracy']

SGDevalloss,SGDevalaccuracy=model.evaluate(x_test,y_test)

print(SGDLoss)
print(SGDAccuracy)

print(SGDevalloss)
print(SGDevalaccuracy)
# Out:
# 313/313 [==============================] - 1s 3ms/step - loss: 0.1610 - accuracy: 0.9532
# [0.6535540223121643, 0.33652907609939575, 0.28635069727897644, 0.25634220242500305, 0.23350228369235992, 0.21527832746505737, 0.19999045133590698, 0.18706367909908295, 0.17566025257110596, 0.16569367051124573]
# [0.8325999975204468, 0.906000018119812, 0.9192500114440918, 0.9281833171844482, 0.9346166849136353, 0.9395666718482971, 0.9441333413124084, 0.9480500221252441, 0.9506666660308838, 0.9538666605949402]
# 0.16104160249233246
# 0.9531999826431274

# %%
model=Sequential([Flatten(input_shape=(28,28)),
                  Dense(128,activation='relu'),
                  Dense(10,activation='softmax')
                  ])
model.compile(optimizer=Adam(learning_rate=0.01),
                          loss='sparse_categorical_crossentropy',
                          metrics=['accuracy'])
Adamvals=model.fit(x_train,y_train,epochs=10)
# Out:
# Epoch 1/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.2465 - accuracy: 0.9271
# Epoch 2/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.1666 - accuracy: 0.9533
# Epoch 3/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.1481 - accuracy: 0.9597
# Epoch 4/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.1346 - accuracy: 0.9643
# Epoch 5/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.1283 - accuracy: 0.9666
# Epoch 6/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.1222 - accuracy: 0.9683
# Epoch 7/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.1162 - accuracy: 0.9700
# Epoch 8/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.1073 - accuracy: 0.9725
# Epoch 9/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.1091 - accuracy: 0.9730
# Epoch 10/10
# ...

# %%
AdamLoss=Adamvals.history['loss']
AdamAccuracy=Adamvals.history['accuracy']

Adamevalloss,Adamevalaccuracy=model.evaluate(x_test,y_test)

print(AdamLoss)
print(AdamAccuracy)

print(Adamevalloss)
print(Adamevalaccuracy)
# Out:
# 313/313 [==============================] - 1s 2ms/step - loss: 0.2850 - accuracy: 0.9580
# [0.24647817015647888, 0.16657902300357819, 0.14811058342456818, 0.1346224844455719, 0.12831692397594452, 0.12221290171146393, 0.11615587025880814, 0.1072758212685585, 0.10906752943992615, 0.10285304486751556]
# [0.9271000027656555, 0.9532666802406311, 0.959683358669281, 0.9642666578292847, 0.966616690158844, 0.9682666659355164, 0.9699666500091553, 0.9724833369255066, 0.9730166792869568, 0.9750833511352539]
# 0.28503087162971497
# 0.9580000042915344

# %%
model=Sequential([Flatten(input_shape=(28,28)),
                  Dense(128,activation='relu'),
                  Dense(10,activation='softmax')
                  ])
model.compile(optimizer=RMSprop(learning_rate=0.01),
                          loss='sparse_categorical_crossentropy',
                          metrics=['accuracy'])
RMSvals=model.fit(x_train,y_train,epochs=10)
# Out:
# Epoch 1/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.2751 - accuracy: 0.9284
# Epoch 2/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.1828 - accuracy: 0.9602
# Epoch 3/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.1680 - accuracy: 0.9680
# Epoch 4/10
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.1494 - accuracy: 0.9713
# Epoch 5/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.1401 - accuracy: 0.9754
# Epoch 6/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.1275 - accuracy: 0.9781
# Epoch 7/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.1265 - accuracy: 0.9793
# Epoch 8/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1122 - accuracy: 0.9812
# Epoch 9/10
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.1050 - accuracy: 0.9827
# Epoch 10/10
# ...

# %%
RMSLoss=RMSvals.history['loss']
RMSAccuracy=RMSvals.history['accuracy']

RMSevalloss,RMSevalaccuracy=model.evaluate(x_test,y_test)

print(RMSLoss)
print(RMSAccuracy)

print(RMSevalloss)
print(RMSevalaccuracy)
# Out:
# 313/313 [==============================] - 1s 2ms/step - loss: 0.2561 - accuracy: 0.9733
# [0.2751077711582184, 0.18281686305999756, 0.16795124113559723, 0.14939531683921814, 0.14007505774497986, 0.12753461301326752, 0.1264583170413971, 0.11221295595169067, 0.10500730574131012, 0.10231874883174896]
# [0.9284166693687439, 0.9602000117301941, 0.9680333137512207, 0.9713166952133179, 0.975350022315979, 0.9780666828155518, 0.9792666435241699, 0.981249988079071, 0.9826666712760925, 0.982699990272522]
# 0.25611990690231323
# 0.9732999801635742

# %%
model=Sequential([Flatten(input_shape=(28,28)),
                  Dense(128,activation='relu'),
                  Dense(10,activation='softmax')
                  ])
model.compile(optimizer=Adagrad(learning_rate=0.01),
                          loss='sparse_categorical_crossentropy',
                          metrics=['accuracy'])
Adagradvals=model.fit(x_train,y_train,epochs=10)
# Out:
# Epoch 1/10
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.4392 - accuracy: 0.8832
# Epoch 2/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.2603 - accuracy: 0.9280
# Epoch 3/10
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.2181 - accuracy: 0.9397
# Epoch 4/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.1907 - accuracy: 0.9470
# Epoch 5/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.1710 - accuracy: 0.9525
# Epoch 6/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1558 - accuracy: 0.9572
# Epoch 7/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.1437 - accuracy: 0.9608
# Epoch 8/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1337 - accuracy: 0.9630
# Epoch 9/10
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.1256 - accuracy: 0.9655
# Epoch 10/10
# ...

# %%
AdagradLoss=Adagradvals.history['loss']
AdagradAccuracy=Adagradvals.history['accuracy']

Adagradevalloss,Adagradevalaccuracy=model.evaluate(x_test,y_test)

print(AdagradLoss)
print(AdagradAccuracy)

print(Adagradevalloss)
print(Adagradevalaccuracy)
# Out:
# 313/313 [==============================] - 1s 2ms/step - loss: 0.1230 - accuracy: 0.9638
# [0.4392402470111847, 0.26031026244163513, 0.2180660218000412, 0.19069810211658478, 0.17099665105342865, 0.1558137685060501, 0.14369989931583405, 0.13373889029026031, 0.1255713254213333, 0.11845897883176804]
# [0.8831666707992554, 0.9280499815940857, 0.9397333264350891, 0.9470333456993103, 0.9524833559989929, 0.9571666717529297, 0.9608333110809326, 0.9630333185195923, 0.9655333161354065, 0.9674666523933411]
# 0.12301849573850632
# 0.9638000130653381

# %%
model=Sequential([Flatten(input_shape=(28,28)),
                  Dense(128,activation='relu'),
                  Dense(10,activation='softmax')
                  ])
model.compile(optimizer=Adadelta(learning_rate=0.01),
                          loss='sparse_categorical_crossentropy',
                          metrics=['accuracy'])
Adadeltavals=model.fit(x_train,y_train,epochs=10)
# Out:
# Epoch 1/10
# 1875/1875 [==============================] - 5s 2ms/step - loss: 1.6355 - accuracy: 0.5814
# Epoch 2/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.8551 - accuracy: 0.8209
# Epoch 3/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.6039 - accuracy: 0.8599
# Epoch 4/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.5010 - accuracy: 0.8760
# Epoch 5/10
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.4460 - accuracy: 0.8852
# Epoch 6/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.4117 - accuracy: 0.8916
# Epoch 7/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.3874 - accuracy: 0.8965
# Epoch 8/10
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.3691 - accuracy: 0.9002
# Epoch 9/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.3546 - accuracy: 0.9035
# Epoch 10/10
# ...

# %%
AdadeltaLoss=Adadeltavals.history['loss']
AdadeltaAccuracy=Adadeltavals.history['accuracy']

Adadeltaevalloss,Adadeltaevalaccuracy=model.evaluate(x_test,y_test)

print(AdadeltaLoss)
print(AdadeltaAccuracy)

print(Adadeltaevalloss)
print(Adadeltaevalaccuracy)
# Out:
# 313/313 [==============================] - 1s 2ms/step - loss: 0.3246 - accuracy: 0.9107
# [1.6354581117630005, 0.8550997972488403, 0.6039457321166992, 0.5009746551513672, 0.44602319598197937, 0.41167813539505005, 0.38736405968666077, 0.3690826892852783, 0.3546200394630432, 0.3427126705646515]
# [0.5813833475112915, 0.8208666443824768, 0.8598833084106445, 0.8760499954223633, 0.885200023651123, 0.8915666937828064, 0.8964999914169312, 0.9002000093460083, 0.9034833312034607, 0.906083345413208]
# 0.32463178038597107
# 0.9107000231742859

# %%
model=Sequential([Flatten(input_shape=(28,28)),
                  Dense(128,activation='relu'),
                  Dense(10,activation='softmax')
                  ])
model.compile(optimizer=Adamax(learning_rate=0.01),
                          loss='sparse_categorical_crossentropy',
                          metrics=['accuracy'])
Adamaxvals=model.fit(x_train,y_train,epochs=10)
# Out:
# Epoch 1/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.2161 - accuracy: 0.9348
# Epoch 2/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0995 - accuracy: 0.9694
# Epoch 3/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0707 - accuracy: 0.9784
# Epoch 4/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0548 - accuracy: 0.9828
# Epoch 5/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0421 - accuracy: 0.9866
# Epoch 6/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0340 - accuracy: 0.9891
# Epoch 7/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0262 - accuracy: 0.9922
# Epoch 8/10
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.0205 - accuracy: 0.9937
# Epoch 9/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0165 - accuracy: 0.9952
# Epoch 10/10
# ...

# %%
AdamaxLoss=Adamaxvals.history['loss']
AdamaxAccuracy=Adamaxvals.history['accuracy']

Adamaxevalloss,Adamaxevalaccuracy=model.evaluate(x_test,y_test)

print(AdamaxLoss)
print(AdamaxAccuracy)

print(Adamaxevalloss)
print(Adamaxevalaccuracy)
# Out:
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0765 - accuracy: 0.9788
# [0.21607789397239685, 0.09954992681741714, 0.07067518681287766, 0.054783932864665985, 0.042129889130592346, 0.034025952219963074, 0.026231367141008377, 0.02054455131292343, 0.01649242267012596, 0.0132446913048625]
# [0.9347500205039978, 0.9693833589553833, 0.9783666729927063, 0.982783317565918, 0.9866166710853577, 0.989133358001709, 0.9921500086784363, 0.9936666488647461, 0.9951500296592712, 0.9959999918937683]
# 0.07650461792945862
# 0.9787999987602234

# %%
model=Sequential([Flatten(input_shape=(28,28)),
                  Dense(128,activation='relu'),
                  Dense(10,activation='softmax')
                  ])
model.compile(optimizer=Nadam(learning_rate=0.01),
                          loss='sparse_categorical_crossentropy',
                          metrics=['accuracy'])
Nadamvals=model.fit(x_train,y_train,epochs=10)
# Out:
# Epoch 1/10
# 1875/1875 [==============================] - 7s 3ms/step - loss: 0.2336 - accuracy: 0.9305
# Epoch 2/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.1557 - accuracy: 0.9559
# Epoch 3/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.1428 - accuracy: 0.9615
# Epoch 4/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.1309 - accuracy: 0.9651
# Epoch 5/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.1256 - accuracy: 0.9682
# Epoch 6/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.1113 - accuracy: 0.9708
# Epoch 7/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.1078 - accuracy: 0.9728
# Epoch 8/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.1091 - accuracy: 0.9731
# Epoch 9/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0977 - accuracy: 0.9762
# Epoch 10/10
# ...

# %%
NadamLoss=Nadamvals.history['loss']
NadamAccuracy=Nadamvals.history['accuracy']

Nadamevalloss,Nadamevalaccuracy=model.evaluate(x_test,y_test)

print(NadamLoss)
print(NadamAccuracy)

print(Nadamevalloss)
print(Nadamevalaccuracy)
# Out:
# 313/313 [==============================] - 1s 3ms/step - loss: 0.2517 - accuracy: 0.9573
# [0.2336103618144989, 0.15565532445907593, 0.1428273320198059, 0.13092057406902313, 0.12555629014968872, 0.11130574345588684, 0.10782457888126373, 0.109145887196064, 0.09773953258991241, 0.0998552143573761]
# [0.9304999709129333, 0.9558500051498413, 0.961483359336853, 0.96506667137146, 0.9681500196456909, 0.9708499908447266, 0.9728000164031982, 0.9731166958808899, 0.9761833548545837, 0.9762666821479797]
# 0.25165170431137085
# 0.9573000073432922

# %%
plt.plot(SGDLoss)
plt.plot(AdamLoss)
plt.plot(RMSLoss)
plt.plot(AdagradLoss)
plt.plot(AdadeltaLoss)
plt.plot(AdamaxLoss)
plt.plot(NadamLoss)
plt.ylabel('Accuracy')
plt.xlabel('epoch')
plt.title("Epoch Loss")
plt.legend( ['SGD ','Adam','RMS','Adagrad','Adadelta','Adamax','Nadam'],loc='upper left', bbox_to_anchor=(1, 0.5))
plt.show()

# %%
plt.plot(SGDAccuracy)
plt.plot(AdamAccuracy)
plt.plot(RMSAccuracy)
plt.plot(AdagradAccuracy)
plt.plot(AdadeltaAccuracy)
plt.plot(AdamaxAccuracy)
plt.plot(NadamAccuracy)
plt.ylabel('Accuracy')
plt.xlabel('epoch')
plt.title("Epoch Accuracy")
plt.legend( ['SGD ','Adam','RMS','Adagrad','Adadelta','Adamax','Nadam'],loc='upper left', bbox_to_anchor=(1, 0.5))
plt.show()

# %%
lst=[SGDevalaccuracy,Adamevalaccuracy,RMSevalaccuracy,Adagradevalaccuracy,Adadeltaevalaccuracy,Adamaxevalaccuracy,Nadamevalaccuracy]
plt.plot(lst)
plt.title("Optimizers Accuracy")
xval=['SGD','Adam','RMS','Adagrad','Adadelta','Adamax','Nadam']
for i in range(len(xval)):
  print("{}:{} ".format(i,xval[i]),end=" ")
plt.show()
# Out:
# 0:SGD  1:Adam  2:RMS  3:Adagrad  4:Adadelta  5:Adamax  6:Nadam

# %%
lst=[SGDevalloss,Adamevalloss,RMSevalloss,Adagradevalloss,Adadeltaevalloss,Adamaxevalloss,Nadamevalloss]
plt.plot(lst)
plt.title("Optimizers Loss")
xval=['SGD','Adam','RMS','Adagrad','Adadelta','Adamax','Nadam']
for i in range(len(xval)):
  print("{}:{} ".format(i,xval[i]),end=" ")
plt.show()
# Out:
# 0:SGD  1:Adam  2:RMS  3:Adagrad  4:Adadelta  5:Adamax  6:Nadam
